# %%
# Creating a model
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.config.list_physical_devices(device_type=None)

from keras.models import Sequential
from keras.layers import Dense

# Custom activation function
from keras.layers import Activation
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects

import numpy as np
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import numpy as np
from keras import layers

from sklearn.metrics import confusion_matrix
import seaborn as sns


import numpy as np
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import numpy as np
from keras import layers

from keras import backend as K

# %%
def custom_activation(x):
    return tf.where(x<0, tf.multiply(x,0), tf.where(x<2.4, tf.multiply(0.6,x),tf.where(x<6.9,tf.add(tf.multiply(0.21,x),0.95),tf.add(tf.multiply(0.5,x),-1.05))))

get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
list1=[]
for i in np.arange(-10,10,0.1):
    a=tf.constant([i])
    b=custom_activation(a)
    list1.append(b)
    
plt.plot(np.arange(-10,10,0.1),list1)

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
train_data = np.expand_dims(x_train, -1)
test_data = np.expand_dims(x_test, -1)


# convert class vectors to binary class matrices
train_label = to_categorical(y_train, num_classes)
test_label = to_categorical(y_test, num_classes)

# %%
epoch_fix=30

# %%
#MNIST relu

input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='relu'),
        layers.Dense(1000,activation='relu'),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Relu=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs,validation_data=(test_data, test_label),verbose=0)



test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#MNIST Sigmoid

input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='sigmoid'),
        layers.Dense(1000,activation='sigmoid'),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Sigmoid=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)



test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")

K.clear_session()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)        0
# 2D)
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              2101248
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#MNIST Bistable
input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation=custom_activation),
        layers.Dense(1000,activation=custom_activation),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history_MNIST_Bistable=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs,validation_data=(test_data, test_label),verbose=0)


test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#MNIST no activation
input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096),
        layers.Dense(1000),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_MNIST_No=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)

test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu")

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plot accuracy vs epochs 
plt.plot(history_MNIST_Relu.history['val_accuracy'])
plt.plot(history_MNIST_Sigmoid.history['val_accuracy'])
plt.plot(history_MNIST_Bistable.history['val_accuracy'])
plt.plot(history_MNIST_No.history['val_accuracy'])
plt.title('model accuracy with different activation function for MNIST')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()


plt.plot(history_MNIST_Relu.history['val_loss'])
plt.plot(history_MNIST_Sigmoid.history['val_loss'])
plt.plot(history_MNIST_Bistable.history['val_loss'])
plt.plot(history_MNIST_No.history['val_loss'])
plt.title('model loss with different activation function for MNIST')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()

print(history_MNIST_Relu.history['val_accuracy'][29],history_MNIST_Relu.history['val_loss'][29])
print(history_MNIST_Sigmoid.history['val_accuracy'][29],history_MNIST_Sigmoid.history['val_loss'][29])
print(history_MNIST_Bistable.history['val_accuracy'][29],history_MNIST_Bistable.history['val_loss'][29])
print(history_MNIST_No.history['val_accuracy'][29],history_MNIST_No.history['val_loss'][29])
# Out:
# 0.9926000237464905 0.061018165200948715
# 0.11349999904632568 2.3179612159729004
# 0.9933000206947327 0.03614262863993645
# 0.9909999966621399 0.1652534008026123

# %%
#Load FashionMNIST

(train_data, train_label), (test_data, test_label) = tf.keras.datasets.fashion_mnist.load_data()

train_label=to_categorical(train_label)
test_label=to_categorical(test_label)

label=["T-Shirt","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Ankle Boot"]
train_data=train_data/255
test_data=test_data/255

# %%
#Fashion MNIST relu
input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='relu'),
        layers.Dense(1000,activation='relu'),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_FashionMNIST_Relu=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)

test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fashion MNIST Sigmoid
input_shape=(28,28)
input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='sigmoid'),
        layers.Dense(1000,activation='sigmoid'),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_FashionMNIST_Sigmoid=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)

test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fashion MNIST Bistable

input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation=custom_activation),
        layers.Dense(1000,activation=custom_activation),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_FashionMNIST_Bistable=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)


test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fashion MNIST no activation
input_shape=(28,28,1)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096),
        layers.Dense(1000),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_FashionMNIST_No=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label),verbose=0)


test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 14, 14, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 3, 3, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 1, 1, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 7,758,082
# Trainable params: 7,758,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Plot accuracy vs epochs 
plt.plot(history_FashionMNIST_Relu.history['val_accuracy'])
plt.plot(history_FashionMNIST_Sigmoid.history['val_accuracy'])
plt.plot(history_FashionMNIST_Bistable.history['val_accuracy'])
plt.plot(history_FashionMNIST_No.history['val_accuracy'])
plt.title('model accuracy with different activation function for FashionMNIST')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()


plt.plot(history_FashionMNIST_Relu.history['val_loss'])
plt.plot(history_FashionMNIST_Sigmoid.history['val_loss'])
plt.plot(history_FashionMNIST_Bistable.history['val_loss'])
plt.plot(history_FashionMNIST_No.history['val_loss'])
plt.title('model loss with different activation function for FashionMNIST')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()

print(history_FashionMNIST_Relu.history['val_accuracy'][29],history_FashionMNIST_Relu.history['val_loss'][29])
print(history_FashionMNIST_Sigmoid.history['val_accuracy'][29],history_FashionMNIST_Sigmoid.history['val_loss'][29])
print(history_FashionMNIST_Bistable.history['val_accuracy'][29],history_FashionMNIST_Bistable.history['val_loss'][29])
print(history_FashionMNIST_No.history['val_accuracy'][29],history_FashionMNIST_No.history['val_loss'][29])
# Out:
# 0.9185000061988831 0.5429877042770386
# 0.10000000149011612 2.3344039916992188
# 0.9168000221252441 0.48149195313453674
# 0.9107000231742859 0.4460289478302002

# %%
#Plot accuracy vs epochs 
plt.plot(history_FashionMNIST_Relu.history['val_accuracy'])
#plt.plot(history_FashionMNIST_Sigmoid.history['val_accuracy'])
plt.plot(history_FashionMNIST_Bistable.history['val_accuracy'])
plt.plot(history_FashionMNIST_No.history['val_accuracy'])
plt.title('model accuracy with different activation function for FashionMNIST')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()


plt.plot(history_FashionMNIST_Relu.history['val_loss'])
#plt.plot(history_FashionMNIST_Sigmoid.history['val_loss'])
plt.plot(history_FashionMNIST_Bistable.history['val_loss'])
plt.plot(history_FashionMNIST_No.history['val_loss'])
plt.title('model loss with different activation function for FashionMNIST')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['ReLu','Bistable nonlinear','Linear'], loc='upper left')
plt.show()

print(history_FashionMNIST_Relu.history['val_accuracy'][29],history_FashionMNIST_Relu.history['val_loss'][29])
print(history_FashionMNIST_Sigmoid.history['val_accuracy'][29],history_FashionMNIST_Sigmoid.history['val_loss'][29])
print(history_FashionMNIST_Bistable.history['val_accuracy'][29],history_FashionMNIST_Bistable.history['val_loss'][29])
print(history_FashionMNIST_No.history['val_accuracy'][29],history_FashionMNIST_No.history['val_loss'][29])
# Out:
# 0.9185000061988831 0.5429877042770386
# 0.10000000149011612 2.3344039916992188
# 0.9168000221252441 0.48149195313453674
# 0.9107000231742859 0.4460289478302002

# %%
from keras.datasets import cifar10
# load dataset
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
# one hot encode target values
train_label = to_categorical(train_label)
test_label = to_categorical(test_label)
train_data=train_data/255
test_data=test_data/255

# %%
label=["airplanes","automobiles","birds","cats","deers","dogs","frogs","horses","ships","trucks"]

# %%
#CIFAR-10 relu
input_shape=(32,32,3)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='relu'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='relu'),
        layers.Dense(1000,activation='relu'),
        layers.Dense(10,activation='softmax'),
    ]
)
model.summary()


batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_CIFAR_Relu=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs,validation_data=(test_data, test_label))
test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 16, 16, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 14,050,690
# Trainable params: 14,050,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 391/391 [==============================] - 7s 15ms/step - loss: 1.5119 - accuracy: 0.4331 - val_loss: 1.1919 - val_accuracy: 0.5685
# Epoch 2/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.9965 - accuracy: 0.6447 - val_loss: 0.8965 - val_accuracy: 0.6848
# Epoch 3/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7702 - accuracy: 0.7278 - val_loss: 0.7978 - val_accuracy: 0.7217
# Epoch 4/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6217 - accuracy: 0.7831 - val_loss: 0.7380 - val_accuracy: 0.7503
# Epoch 5/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.5059 - accuracy: 0.8230 - val_loss: 0.7818 - val_accuracy: 0.7426
# Epoch 6/30
# 391/391 [==============================] - 5s 14ms/step - loss: 0.4083 - accuracy: 0.8567 - val_loss: 0.7938 - val_accuracy: 0.7509
# Epoch 7/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3236 - accuracy: 0.8872 - val_loss: 0.9227 - val_accuracy: 0.7277
# Epoch 8/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2611 - accuracy: 0.9081 - val_loss: 0.8960 - val_accuracy: 0.7556
# Epoch 9/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2009 - accuracy: 0.9295 - val_loss: 1.0509 - val_accuracy: 0.7457
# Epoch 10/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1715 - accuracy: 0.9398 - val_loss: 0.9885 - val_accuracy: 0.7471
# Epoch 11/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1355 - accuracy: 0.9527 - val_loss: 1.1158 - val_accuracy: 0.7460
# Epoch 12/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1377 - accuracy: 0.9519 - val_loss: 1.1313 - val_accuracy: 0.7543
# Epoch 13/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1090 - accuracy: 0.9618 - val_loss: 1.2843 - val_accuracy: 0.7536
# Epoch 14/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0961 - accuracy: 0.9667 - val_loss: 1.1997 - val_accuracy: 0.7431
# Epoch 15/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0842 - accuracy: 0.9706 - val_loss: 1.3443 - val_accuracy: 0.7477
# Epoch 16/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0802 - accuracy: 0.9721 - val_loss: 1.3918 - val_accuracy: 0.7508
# Epoch 17/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0781 - accuracy: 0.9732 - val_loss: 1.4121 - val_accuracy: 0.7458
# Epoch 18/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0669 - accuracy: 0.9767 - val_loss: 1.4949 - val_accuracy: 0.7378
# Epoch 19/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0811 - accuracy: 0.9730 - val_loss: 1.5181 - val_accuracy: 0.7453
# Epoch 20/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0638 - accuracy: 0.9793 - val_loss: 1.5246 - val_accuracy: 0.7494
# Epoch 21/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0576 - accuracy: 0.9800 - val_loss: 1.5205 - val_accuracy: 0.7437
# Epoch 22/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0669 - accuracy: 0.9780 - val_loss: 1.4191 - val_accuracy: 0.7391
# Epoch 23/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0610 - accuracy: 0.9791 - val_loss: 1.5233 - val_accuracy: 0.7515
# Epoch 24/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0583 - accuracy: 0.9806 - val_loss: 1.5503 - val_accuracy: 0.7482
# Epoch 25/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0548 - accuracy: 0.9814 - val_loss: 1.5046 - val_accuracy: 0.7432
# Epoch 26/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0476 - accuracy: 0.9847 - val_loss: 1.7201 - val_accuracy: 0.7403
# Epoch 27/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0564 - accuracy: 0.9816 - val_loss: 1.6276 - val_accuracy: 0.7547
# Epoch 28/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0521 - accuracy: 0.9829 - val_loss: 1.6541 - val_accuracy: 0.7423
# Epoch 29/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0516 - accuracy: 0.9829 - val_loss: 1.6035 - val_accuracy: 0.7538
# Epoch 30/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0509 - accuracy: 0.9836 - val_loss: 1.5246 - val_accuracy: 0.7551

# %%
#CIFAR-10 Sigmoid
input_shape=(32,32,3)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation='sigmoid'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation='sigmoid'),
        layers.Dense(1000,activation='sigmoid'),
        layers.Dense(10,activation='softmax'),
    ]
)
model.summary()


batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_CIFAR_Sigmoid=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label))
test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 16, 16, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 14,050,690
# Trainable params: 14,050,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 391/391 [==============================] - 7s 15ms/step - loss: 2.3881 - accuracy: 0.0988 - val_loss: 2.3189 - val_accuracy: 0.1000
# Epoch 2/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3228 - accuracy: 0.0984 - val_loss: 2.3231 - val_accuracy: 0.1000
# Epoch 3/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3251 - accuracy: 0.0971 - val_loss: 2.3192 - val_accuracy: 0.1000
# Epoch 4/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3238 - accuracy: 0.1026 - val_loss: 2.3254 - val_accuracy: 0.1000
# Epoch 5/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3246 - accuracy: 0.1001 - val_loss: 2.3281 - val_accuracy: 0.1000
# Epoch 6/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3262 - accuracy: 0.0998 - val_loss: 2.3130 - val_accuracy: 0.1000
# Epoch 7/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3266 - accuracy: 0.0975 - val_loss: 2.3216 - val_accuracy: 0.1000
# Epoch 8/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3257 - accuracy: 0.0994 - val_loss: 2.3232 - val_accuracy: 0.1000
# Epoch 9/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3249 - accuracy: 0.0982 - val_loss: 2.3259 - val_accuracy: 0.1000
# Epoch 10/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3239 - accuracy: 0.0978 - val_loss: 2.3256 - val_accuracy: 0.1000
# Epoch 11/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3235 - accuracy: 0.0985 - val_loss: 2.3246 - val_accuracy: 0.1000
# Epoch 12/30
# 391/391 [==============================] - 6s 14ms/step - loss: 2.3227 - accuracy: 0.1030 - val_loss: 2.3204 - val_accuracy: 0.1000
# Epoch 13/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3255 - accuracy: 0.1023 - val_loss: 2.3489 - val_accuracy: 0.1000
# Epoch 14/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3239 - accuracy: 0.1002 - val_loss: 2.3398 - val_accuracy: 0.1000
# Epoch 15/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3272 - accuracy: 0.0999 - val_loss: 2.3250 - val_accuracy: 0.1000
# Epoch 16/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3269 - accuracy: 0.0986 - val_loss: 2.3122 - val_accuracy: 0.1000
# Epoch 17/30
# 391/391 [==============================] - 6s 14ms/step - loss: 2.3240 - accuracy: 0.0970 - val_loss: 2.3380 - val_accuracy: 0.1000
# Epoch 18/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3264 - accuracy: 0.1006 - val_loss: 2.3316 - val_accuracy: 0.1000
# Epoch 19/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3261 - accuracy: 0.0985 - val_loss: 2.3116 - val_accuracy: 0.1000
# Epoch 20/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3237 - accuracy: 0.0999 - val_loss: 2.3328 - val_accuracy: 0.1000
# Epoch 21/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3279 - accuracy: 0.0991 - val_loss: 2.3183 - val_accuracy: 0.1000
# Epoch 22/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3256 - accuracy: 0.0992 - val_loss: 2.3207 - val_accuracy: 0.1000
# Epoch 23/30
# 391/391 [==============================] - 6s 14ms/step - loss: 2.3253 - accuracy: 0.1019 - val_loss: 2.3144 - val_accuracy: 0.1000
# Epoch 24/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3258 - accuracy: 0.1000 - val_loss: 2.3216 - val_accuracy: 0.1000
# Epoch 25/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3240 - accuracy: 0.0966 - val_loss: 2.3305 - val_accuracy: 0.1000
# Epoch 26/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3238 - accuracy: 0.1026 - val_loss: 2.3340 - val_accuracy: 0.1000
# Epoch 27/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3250 - accuracy: 0.1018 - val_loss: 2.3213 - val_accuracy: 0.1000
# Epoch 28/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3282 - accuracy: 0.1004 - val_loss: 2.3219 - val_accuracy: 0.1000
# Epoch 29/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3260 - accuracy: 0.1010 - val_loss: 2.3387 - val_accuracy: 0.1000
# Epoch 30/30
# 391/391 [==============================] - 5s 14ms/step - loss: 2.3240 - accuracy: 0.1013 - val_loss: 2.3600 - val_accuracy: 0.1000

# %%
#CIFAR-10 Bistable
input_shape=(32,32,3)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same',activation=custom_activation),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096,activation=custom_activation),
        layers.Dense(1000,activation=custom_activation),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_CIFAR_Bistable=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label))
test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 16, 16, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 14,050,690
# Trainable params: 14,050,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 391/391 [==============================] - 12s 28ms/step - loss: 1.6721 - accuracy: 0.3659 - val_loss: 1.3309 - val_accuracy: 0.5161
# Epoch 2/30
# 391/391 [==============================] - 10s 26ms/step - loss: 1.1444 - accuracy: 0.5835 - val_loss: 1.0300 - val_accuracy: 0.6237
# Epoch 3/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.8928 - accuracy: 0.6835 - val_loss: 0.8999 - val_accuracy: 0.6828
# Epoch 4/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.7330 - accuracy: 0.7421 - val_loss: 0.7866 - val_accuracy: 0.7245
# Epoch 5/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.5907 - accuracy: 0.7921 - val_loss: 0.7235 - val_accuracy: 0.7500
# Epoch 6/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.4834 - accuracy: 0.8318 - val_loss: 0.7606 - val_accuracy: 0.7467
# Epoch 7/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.3773 - accuracy: 0.8689 - val_loss: 0.7774 - val_accuracy: 0.7592
# Epoch 8/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.2817 - accuracy: 0.9020 - val_loss: 0.8226 - val_accuracy: 0.7591
# Epoch 9/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.2198 - accuracy: 0.9219 - val_loss: 0.8989 - val_accuracy: 0.7604
# Epoch 10/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.1675 - accuracy: 0.9404 - val_loss: 0.9904 - val_accuracy: 0.7520
# Epoch 11/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.1389 - accuracy: 0.9524 - val_loss: 1.0679 - val_accuracy: 0.7534
# Epoch 12/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.1077 - accuracy: 0.9619 - val_loss: 1.1324 - val_accuracy: 0.7618
# Epoch 13/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0957 - accuracy: 0.9666 - val_loss: 1.1220 - val_accuracy: 0.7633
# Epoch 14/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.1000 - accuracy: 0.9653 - val_loss: 1.2002 - val_accuracy: 0.7574
# Epoch 15/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0742 - accuracy: 0.9740 - val_loss: 1.2131 - val_accuracy: 0.7600
# Epoch 16/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0738 - accuracy: 0.9737 - val_loss: 1.2642 - val_accuracy: 0.7568
# Epoch 17/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0671 - accuracy: 0.9760 - val_loss: 1.3382 - val_accuracy: 0.7545
# Epoch 18/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0614 - accuracy: 0.9786 - val_loss: 1.3566 - val_accuracy: 0.7532
# Epoch 19/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0602 - accuracy: 0.9795 - val_loss: 1.3571 - val_accuracy: 0.7621
# Epoch 20/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0561 - accuracy: 0.9807 - val_loss: 1.4414 - val_accuracy: 0.7493
# Epoch 21/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0538 - accuracy: 0.9811 - val_loss: 1.3179 - val_accuracy: 0.7553
# Epoch 22/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0508 - accuracy: 0.9819 - val_loss: 1.3286 - val_accuracy: 0.7495
# Epoch 23/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0487 - accuracy: 0.9836 - val_loss: 1.3579 - val_accuracy: 0.7618
# Epoch 24/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0441 - accuracy: 0.9848 - val_loss: 1.3617 - val_accuracy: 0.7600
# Epoch 25/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0373 - accuracy: 0.9874 - val_loss: 1.4501 - val_accuracy: 0.7547
# Epoch 26/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0483 - accuracy: 0.9840 - val_loss: 1.3199 - val_accuracy: 0.7570
# Epoch 27/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0405 - accuracy: 0.9861 - val_loss: 1.4607 - val_accuracy: 0.7534
# Epoch 28/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0377 - accuracy: 0.9875 - val_loss: 1.4899 - val_accuracy: 0.7523
# Epoch 29/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0396 - accuracy: 0.9866 - val_loss: 1.5393 - val_accuracy: 0.7498
# Epoch 30/30
# 391/391 [==============================] - 10s 26ms/step - loss: 0.0383 - accuracy: 0.9871 - val_loss: 1.5092 - val_accuracy: 0.7456

# %%
#CIFAR-10 no activation
input_shape=(32,32,3)
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(64, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(512, (3, 3), padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(4096),
        layers.Dense(1000),
        layers.Dense(10,activation='softmax'),
    ]
)

model.summary()

batch_size = 128
epochs = epoch_fix
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history_CIFAR_No=model.fit(train_data, train_label, batch_size=batch_size, epochs=epochs, validation_data=(test_data, test_label))
test_predictions = model.predict(test_data)
cm = confusion_matrix(y_true = np.argmax(test_label,axis=1), y_pred = np.argmax(test_predictions,axis=1))
sns.heatmap(cm,annot=True,fmt='d',linewidths=2,cmap="YlGnBu",xticklabels=label,yticklabels=label)

K.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D  (None, 16, 16, 64)        0
# )
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)         0
# 2D)
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)         0
# 2D)
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling  (None, 2, 2, 512)         0
# 2D)
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              8392704
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 14,050,690
# Trainable params: 14,050,690
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 391/391 [==============================] - 6s 13ms/step - loss: 1.6055 - accuracy: 0.4773 - val_loss: 1.1201 - val_accuracy: 0.6122
# Epoch 2/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.9752 - accuracy: 0.6625 - val_loss: 1.0047 - val_accuracy: 0.6533
# Epoch 3/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.7828 - accuracy: 0.7284 - val_loss: 0.8458 - val_accuracy: 0.7163
# Epoch 4/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6386 - accuracy: 0.7793 - val_loss: 0.8436 - val_accuracy: 0.7216
# Epoch 5/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.5161 - accuracy: 0.8233 - val_loss: 0.9910 - val_accuracy: 0.7084
# Epoch 6/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.4198 - accuracy: 0.8536 - val_loss: 1.0130 - val_accuracy: 0.7080
# Epoch 7/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3281 - accuracy: 0.8879 - val_loss: 1.0662 - val_accuracy: 0.7066
# Epoch 8/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2681 - accuracy: 0.9097 - val_loss: 1.1173 - val_accuracy: 0.7184
# Epoch 9/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2407 - accuracy: 0.9199 - val_loss: 1.3281 - val_accuracy: 0.7094
# Epoch 10/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2225 - accuracy: 0.9257 - val_loss: 1.3843 - val_accuracy: 0.7137
# Epoch 11/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2211 - accuracy: 0.9274 - val_loss: 1.2288 - val_accuracy: 0.7281
# Epoch 12/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2015 - accuracy: 0.9365 - val_loss: 1.9475 - val_accuracy: 0.6724
# Epoch 13/30
# 391/391 [==============================] - 5s 13ms/step - loss: 617.9871 - accuracy: 0.5167 - val_loss: 6.8717 - val_accuracy: 0.5396
# Epoch 14/30
# 391/391 [==============================] - 5s 13ms/step - loss: 3.1754 - accuracy: 0.6816 - val_loss: 3.5993 - val_accuracy: 0.6251
# Epoch 15/30
# 391/391 [==============================] - 5s 13ms/step - loss: 1.4648 - accuracy: 0.7727 - val_loss: 2.7975 - val_accuracy: 0.6506
# Epoch 16/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.8880 - accuracy: 0.8236 - val_loss: 2.3320 - val_accuracy: 0.6688
# Epoch 17/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.6031 - accuracy: 0.8579 - val_loss: 2.0384 - val_accuracy: 0.6898
# Epoch 18/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.4383 - accuracy: 0.8837 - val_loss: 1.9011 - val_accuracy: 0.6944
# Epoch 19/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.3232 - accuracy: 0.9051 - val_loss: 1.7721 - val_accuracy: 0.7013
# Epoch 20/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.2538 - accuracy: 0.9208 - val_loss: 1.7004 - val_accuracy: 0.7044
# Epoch 21/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1945 - accuracy: 0.9354 - val_loss: 1.6667 - val_accuracy: 0.7109
# Epoch 22/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1539 - accuracy: 0.9483 - val_loss: 1.6471 - val_accuracy: 0.7194
# Epoch 23/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.1181 - accuracy: 0.9603 - val_loss: 1.6340 - val_accuracy: 0.7166
# Epoch 24/30
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0907 - accuracy: 0.9696 - val_loss: 1.6625 - val_accuracy: 0.7222
# Epoch 25/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0677 - accuracy: 0.9784 - val_loss: 1.6941 - val_accuracy: 0.7201
# Epoch 26/30
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0486 - accuracy: 0.9859 - val_loss: 1.7444 - val_accuracy: 0.7240
# Epoch 27/30
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0339 - accuracy: 0.9914 - val_loss: 1.8133 - val_accuracy: 0.7273
# Epoch 28/30
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0227 - accuracy: 0.9955 - val_loss: 1.9249 - val_accuracy: 0.7220
# Epoch 29/30
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0143 - accuracy: 0.9980 - val_loss: 1.9627 - val_accuracy: 0.7290
# Epoch 30/30
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0090 - accuracy: 0.9994 - val_loss: 2.0216 - val_accuracy: 0.7315

# %%
#Plot accuracy vs epochs 
plt.plot(history_CIFAR_Relu.history['val_accuracy'])
plt.plot(history_CIFAR_Sigmoid.history['val_accuracy'])
plt.plot(history_CIFAR_Bistable.history['val_accuracy'])
plt.plot(history_CIFAR_No.history['val_accuracy'])
plt.title('model accuracy with different activation function for CIFAR')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()


plt.plot(history_CIFAR_Relu.history['val_loss'])
plt.plot(history_CIFAR_Sigmoid.history['val_loss'])
plt.plot(history_CIFAR_Bistable.history['val_loss'])
plt.plot(history_CIFAR_No.history['val_loss'])
plt.title('model loss with different activation function for CIFAR')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['ReLu', 'Sigmoid','Bistable nonlinear','Linear'], loc='upper left')
plt.show()
